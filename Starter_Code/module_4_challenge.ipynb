# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')

df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
df.tail()
# Out:
#          first       last                      job               phone  \
# 54634   Lauren      Reese           Radio producer  977.877.5272x11382
# 54635  Derrick      Moore                 Musician        358.661.5483
# 54636   Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637    Wanda    Solomon             Toxicologist       (311)767-4924
# 54638   Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                     email  client_id  order_id  order_date  \
# 54634  late_reese_4081@montoya-chavez.org      29043   9021716  2023-04-26
# 54635        derrick.moore.2602@pope.info      41908   6290153  2023-02-08
# 54636           gutierrezm3195@morris.org      35176   8692622  2023-03-05
# 54637           solomonwanda5962@ross.org      24485   7592730  2023-01-18
# 54638                    belld@galvan.com      24007   7489403  2023-01-04
#
#        order_week  order_year         item_id     category  \
# ...

# %%
df.shape
# Out:
# (54639, 18)

# %%
# What three item categories had the most entries?
df_top_three = df['category'].value_counts()
df_top_three.head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries,
# which subcategory had the most entries?
top_top = df[['category','subcategory']].value_counts()
top_top.head(1)
# Out:
# category     subcategory
# consumables  bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Which five clients had the most entries in the data?
top_five = df['client_id'].value_counts()
top_five.head()

# im goin to start adding in notes, because the questions following this dont really make sense... 
# this questions specifically asks for "most entries in the data", arranged by entries in data client 33615 
# appears 220 times. this isnt asking for the highest sales, highest quantity/best client, just the most entries.
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
top_five = df['client_id'].value_counts()
top_list = top_five.head(5)
top_list.index

#this is the list, can also use .tolist() in order to create... of the top 5 clients with the most entries in the data
# Out:
# Index([33615, 66037, 46820, 38378, 24741], dtype='int64', name='client_id')

# %%
best_client_value = df['qty'].sort_values(ascending=False)
best_client_value.head(1)

# conversely this is the client with the most quantity ordered... not the most quantity by entries.
# Out:
# 21801    3958244
# Name: qty, dtype: int64

# %%
#here is Jessica Reyes, the top client by most order entries, by order ID.

top_client_by_order = df[df.eq(33615).any(axis=1)]
top_client_by_order.head()
# Out:
#         first   last                                           job  \
# 5     Jessica  Reyes  Production designer, theatre/television/film
# 12    Jessica  Reyes  Production designer, theatre/television/film
# 724   Jessica  Reyes  Production designer, theatre/television/film
# 840   Jessica  Reyes  Production designer, theatre/television/film
# 1405  Jessica  Reyes  Production designer, theatre/television/film
#
#            phone                     email  client_id  order_id  order_date  \
# 5     5016915923  jessica.reyes@grimes.net      33615   1327730  2023-05-02
# 12    5016915923  jessica.reyes@grimes.net      33615   6059361  2023-05-16
# 724   5016915923  jessica.reyes@grimes.net      33615   7417275  2023-05-24
# 840   5016915923  jessica.reyes@grimes.net      33615   1951089  2023-02-15
# 1405  5016915923  jessica.reyes@grimes.net      33615   5615970  2023-04-19
#
#       order_week  order_year         item_id     category     subcategory  \
# ...

# %%
## How many total units (the qty column) did the
# client with the most entries order order?

#answer; 64,313 total units.  vs 3.9m units ordered by the largest volume client.

top_client_by_order['qty'].sum()
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the 
# subtotal for each line using the unit_price
# and the qty

df['qty'].astype(float)
df['line_subtotal'] = df['unit_price'] * df['qty']
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.

def shipping_price(row):
    order_weight = row['unit_weight'] * row['qty']
    if (order_weight > 50):
        return order_weight * 7
    else: 
        return order_weight * 10
df['shipping_price'] = df.apply(shipping_price, axis=1)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%

df['total_price_tax'] = round((df['shipping_price'] + df['line_subtotal'])  * 1.0925, 2)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...     category         subcategory unit_price  \
# ...

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).

df['total_cost'] = round(df['shipping_price'] + ( df['unit_cost'] * df['qty']), 2)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...         subcategory unit_price unit_cost  \
# ...

# %%
# Create a column for the profit of
# each line using line cost and line price
df['profit'] = round(df['total_price_tax'] - df['total_cost'], 2)
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_price unit_cost unit_weight  qty  \
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# step 2 sum the totals of all those orders, answer is sliced to show only what was asked; 
# answers dont match your totals

df.set_index('order_id')
df[(df['order_id'] == 2173913)]
total_order = df[(df['order_id'] == 2173913)].sum()
total_order[-3:-2]
# Out:
# total_price_tax    162388.71
# dtype: object

# %%
df.set_index('order_id')
df[(df['order_id'] == 2742071)]
total_order = df[(df['order_id'] == 2742071)].sum()
total_order[-3:-2]
# Out:
# total_price_tax    152811.89
# dtype: object

# %%
df.set_index('order_id')
df[(df['order_id'] == 6128929)]
total_order = df[(df['order_id'] == 6128929)].sum()
total_order[-3:-2]
# Out:
# total_price_tax    923441.25
# dtype: object

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.

# top 5 clients by quantity.. of what??? quantity is a different total than whats above in part 1. lol. 
# heres the top 5 by quantity, up top you ask for the top 5 clients by entries in the data. if one client has 200
# entries at 1 item per entry and another client has 250 items in 1 entry, who has more entries? the one with less qty

top_drop = df.drop(['first', 'last', 'job', 'phone', 'email','order_date', 'order_week', 'order_year', 'item_id', 'category',\
                    'subcategory', 'unit_price', 'order_id', 'total_cost', 'shipping_price', 'line_subtotal', 'line_number', 'unit_cost', 'profit', 'unit_weight'], axis=1)
top_drop.sort_values('qty', ascending=False).head(5)
# Out:
#        client_id      qty  total_price_tax
# 21801      78965  3958244     6.412625e+08
# 25972      86721   977121     1.760742e+08
# 8761       30143   842581     3.256799e+07
# 15112      85931   637318     2.359589e+08
# 50048      77354   494692     6.902100e+07

# %%
# alternatively we can do the previous sections client ID's 
top_client_ids = [33615, 66037, 46820, 38378, 24741]
mask = df['client_id'].isin(top_client_ids)
top_clients = df[mask]
top_clients_sum = top_clients.groupby('client_id')['total_price_tax'].sum()
top_clients_sum.map('${: ,.2f}'.format)
# Out:
# client_id
# 24741    $ 82,268,892.02
# 33615     $ 8,377,308.52
# 38378    $ 12,906,550.87
# 46820     $ 9,743,794.36
# 66037    $ 10,259,514.79
# Name: total_price_tax, dtype: object

# %%
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number', 'line_subtotal', 'shipping_price', 'total_price_tax',
#        'total_cost', 'profit'],
#       dtype='object')

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.

part_four_final_frame = pd.DataFrame({
    'Total Price': top_clients.groupby('client_id')['total_price_tax'].sum(),
    'Total Price Tax': top_clients.groupby('client_id')['total_price_tax'].sum(),
    'Total Units Purchased': top_clients.groupby('client_id')['qty'].sum(),
    'Total Shipping Price': top_clients.groupby('client_id')['shipping_price'].sum(),
    'Total Revenue': top_clients.groupby('client_id')['total_price_tax'].sum(),
    'Total Profit': top_clients.groupby('client_id')['profit'].sum()
})
part_four_sorted = part_four_final_frame.sort_values('Total Profit', ascending=False)
part_four_sorted
# Out:
#            Total Price  Total Price Tax  Total Units Purchased  \
# client_id
# 24741      82268892.02      82268892.02                 239862
# 38378      12906550.87      12906550.87                  73667
# 66037      10259514.79      10259514.79                  43018
# 46820       9743794.36       9743794.36                  75768
# 33615       8377308.52       8377308.52                  64313
#
#            Total Shipping Price  Total Revenue  Total Profit
# client_id
# 24741                5126448.37    82268892.02   36579992.31
# 38378                3429455.40    12906550.87    3271829.89
# 66037                1395151.85    10259514.79    3255031.81
# 46820                1601448.84     9743794.36    2736602.72
# 33615                1828984.89     8377308.52    2201994.61

# %%
part_four_formatted = part_four_sorted.map(lambda value: f'${value/1000000:.2f}M'\
if isinstance(value, (float)) else value)
part_four_formatted

# i had to have the internet teach me how to do this, and i still do not understand it at all. i tried the def millions(value)
# method and i just could not get it to work
# Out:
#           Total Price Total Price Tax  Total Units Purchased  \
# client_id
# 24741         $82.27M         $82.27M                 239862
# 38378         $12.91M         $12.91M                  73667
# 66037         $10.26M         $10.26M                  43018
# 46820          $9.74M          $9.74M                  75768
# 33615          $8.38M          $8.38M                  64313
#
#           Total Shipping Price Total Revenue Total Profit
# client_id
# 24741                   $5.13M       $82.27M      $36.58M
# 38378                   $3.43M       $12.91M       $3.27M
# 66037                   $1.40M       $10.26M       $3.26M
# 46820                   $1.60M        $9.74M       $2.74M
# 33615                   $1.83M        $8.38M       $2.20M

# %%
part_four_formatted_index = part_four_formatted.reset_index()
part_four_formatted_index
# Out:
#    client_id Total Price Total Price Tax  Total Units Purchased  \
# 0      24741     $82.27M         $82.27M                 239862
# 1      38378     $12.91M         $12.91M                  73667
# 2      66037     $10.26M         $10.26M                  43018
# 3      46820      $9.74M          $9.74M                  75768
# 4      33615      $8.38M          $8.38M                  64313
#
#   Total Shipping Price Total Revenue Total Profit
# 0               $5.13M       $82.27M      $36.58M
# 1               $3.43M       $12.91M       $3.27M
# 2               $1.40M       $10.26M       $3.26M
# 3               $1.60M        $9.74M       $2.74M
# 4               $1.83M        $8.38M       $2.20M

# %%
part_four_more = part_four_formatted_index.rename(columns={
'client_id': 'Client ID',
'Total Units Purchased': 'Units',
'Total Shipping Price': 'Shipping',
'Total Price Tax': 'Total Revenue',
'Total Price Tax': 'Total Cost'})

part_four_more
# Out:
#    Client ID Total Price Total Cost   Units Shipping Total Revenue  \
# 0      24741     $82.27M    $82.27M  239862   $5.13M       $82.27M
# 1      38378     $12.91M    $12.91M   73667   $3.43M       $12.91M
# 2      66037     $10.26M    $10.26M   43018   $1.40M       $10.26M
# 3      46820      $9.74M     $9.74M   75768   $1.60M        $9.74M
# 4      33615      $8.38M     $8.38M   64313   $1.83M        $8.38M
#
#   Total Profit
# 0      $36.58M
# 1       $3.27M
# 2       $3.26M
# 3       $2.74M
# 4       $2.20M

# %%
# Sort the updated data by "Total Profit" form highest to lowest
part_four_more.sort_values('Total Profit', ascending=False)
# Out:
#    Client ID Total Price Total Cost   Units Shipping Total Revenue  \
# 0      24741     $82.27M    $82.27M  239862   $5.13M       $82.27M
# 1      38378     $12.91M    $12.91M   73667   $3.43M       $12.91M
# 2      66037     $10.26M    $10.26M   43018   $1.40M       $10.26M
# 3      46820      $9.74M     $9.74M   75768   $1.60M        $9.74M
# 4      33615      $8.38M     $8.38M   64313   $1.83M        $8.38M
#
#   Total Profit
# 0      $36.58M
# 1       $3.27M
# 2       $3.26M
# 3       $2.74M
# 4       $2.20M
